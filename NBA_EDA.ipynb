# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel("/Users/lokeshreddy/Downloads/alltimeleaders.xlsx")

# %%
df.columns
# Out:
# Index(['Unnamed: 0', 'Player', 'GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM',
#        '3PA', '3P%', 'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'STL',
#        'BLK', 'TOV', 'eFG%', 'TS%'],
#       dtype='object')

# %%
#Dropping the column
df1 = df.drop(['Unnamed: 0'], axis = 1)

# %%
df1
# Out:
#                    Player     GP    MIN    PTS    FGM    FGA   FG%   3PM  \
# 0     Kareem Abdul Jabbar  1,560  57446  38387  15837  28307  55.9     1
# 1             Karl Malone  1,476  54852  36928  13528  26210  51.6    85
# 2            LeBron James  1,265  48550  34241  12481  24781  50.4  1875
# 3             Kobe Bryant  1,346  48643  33643  11719  26200  44.7  1827
# 4          Michael Jordan  1,072  41010  32292  12192  24537  49.7   581
# ...                   ...    ...    ...    ...    ...    ...   ...   ...
# 1277        Jim McIlvaine    401   5931   1072    423    948  44.6     1
# 1278         Joel Anthony    490   7056   1064    398    776  51.3     0
# 1279        Greg Dreiling    474   4239   1014    375    803  46.7     3
# 1280          Mark Madsen    453   5335    975    381    834  45.7     1
# 1281       Michael Ruffin    414   5966    716    258    634  40.7     0
#
#        3PA   3P%  ...   FT%  OREB   DREB    REB   AST   STL   BLK   TOV  eFG%  \
# ...

# %%
df1.columns
# Out:
# Index(['Player', 'GP', 'MIN', 'PTS', 'FGM', 'FGA', 'FG%', '3PM', '3PA', '3P%',
#        'FTM', 'FTA', 'FT%', 'OREB', 'DREB', 'REB', 'AST', 'STL', 'BLK', 'TOV',
#        'eFG%', 'TS%'],
#       dtype='object')

# %%
df1.shape
# Out:
# (1282, 22)

# %%
print("GP Games Played\nMIN Minutes Played\nPTS Points\nFGM Field Goals Made\nFGA Field Goals Attempted\nFG% Field Goal Percentage\n3PM 3 Point Field Goals Made\n3PA 3 Point Field Goals Attempted\n3P% 3 Point Field Goals Percentage\nFTM Free Throws Made\nFTA Free Throws Attempted\nFT% Free Throw Percentage\nOREB Offensive Rebounds\nDREB Defensive Rebounds\nREB Rebounds\nAST Assists\nSTL Steals\nBLK Blocks\nTOV Turnovers\neFG% Effective Field Goal Percentage\nTS% True Shooting Percentage")
# Out:
# GP Games Played
# MIN Minutes Played
# PTS Points
# FGM Field Goals Made
# FGA Field Goals Attempted
# FG% Field Goal Percentage
# 3PM 3 Point Field Goals Made
# 3PA 3 Point Field Goals Attempted
# 3P% 3 Point Field Goals Percentage
# FTM Free Throws Made
# FTA Free Throws Attempted
# FT% Free Throw Percentage
# OREB Offensive Rebounds
# DREB Defensive Rebounds
# REB Rebounds
# AST Assists
# STL Steals
# BLK Blocks
# TOV Turnovers
# eFG% Effective Field Goal Percentage
# TS% True Shooting Percentage

# %%
df1.head(10)
# Out:
#                 Player     GP    MIN    PTS    FGM    FGA   FG%   3PM   3PA  \
# 0  Kareem Abdul Jabbar  1,560  57446  38387  15837  28307  55.9     1    18
# 1          Karl Malone  1,476  54852  36928  13528  26210  51.6    85   310
# 2         LeBron James  1,265  48550  34241  12481  24781  50.4  1875  5453
# 3          Kobe Bryant  1,346  48643  33643  11719  26200  44.7  1827  5546
# 4       Michael Jordan  1,072  41010  32292  12192  24537  49.7   581  1778
# 5        Dirk Nowitzki  1,522  51367  31560  11169  23734  47.1  1982  5210
# 6     Wilt Chamberlain  1,045  47859  31419  12681  23497  54.0
# 7     Shaquille O'Neal  1,207  41917  28596  11330  19457  58.2     1    22
# 8         Moses Malone  1,329  45071  27409   9435  19225  49.1     8    80
# 9          Elvin Hayes  1,303  50000  27313  10976  24272  45.2     5    34
#
#     3P%  ...   FT%  OREB   DREB    REB   AST   STL   BLK   TOV  eFG%   TS%
# ...

# %%
df2 = df1.fillna(0)

# %%
df2.isnull().sum()
# Out:
# Player    0
# GP        0
# MIN       0
# PTS       0
# FGM       0
# FGA       0
# FG%       0
# 3PM       0
# 3PA       0
# 3P%       0
# FTM       0
# FTA       0
# FT%       0
# OREB      0
# DREB      0
# REB       0
# AST       0
# STL       0
# BLK       0
# TOV       0
# eFG%      0
# TS%       0
# dtype: int64

# %%
df2.head(10)
# Out:
#                 Player     GP    MIN    PTS    FGM    FGA   FG%   3PM   3PA  \
# 0  Kareem Abdul Jabbar  1,560  57446  38387  15837  28307  55.9     1    18
# 1          Karl Malone  1,476  54852  36928  13528  26210  51.6    85   310
# 2         LeBron James  1,265  48550  34241  12481  24781  50.4  1875  5453
# 3          Kobe Bryant  1,346  48643  33643  11719  26200  44.7  1827  5546
# 4       Michael Jordan  1,072  41010  32292  12192  24537  49.7   581  1778
# 5        Dirk Nowitzki  1,522  51367  31560  11169  23734  47.1  1982  5210
# 6     Wilt Chamberlain  1,045  47859  31419  12681  23497  54.0
# 7     Shaquille O'Neal  1,207  41917  28596  11330  19457  58.2     1    22
# 8         Moses Malone  1,329  45071  27409   9435  19225  49.1     8    80
# 9          Elvin Hayes  1,303  50000  27313  10976  24272  45.2     5    34
#
#     3P%  ...   FT%  OREB   DREB    REB   AST   STL   BLK   TOV  eFG%   TS%
# ...

# %%
plt.figure(figsize=(20,10))
plt.xticks(rotation=90) #For The Angle of labels 
plt.title('Points By Players')
df0 = sns.barplot(x= df2.Player, y= df2.PTS)
df0.set(xlabel='Players',ylabel='Points');

# %%
df2.describe()
# Out:
#                 MIN           PTS           FGM           FGA          FG%  \
# count   1282.000000   1282.000000   1282.000000   1282.000000  1282.000000
# mean   18605.698128   8216.203588   3138.305772   6821.569423    45.771217
# std     9034.030932   5403.431435   2037.171093   4236.698543     4.337357
# min     1352.000000    716.000000    258.000000    634.000000    27.200000
# 25%    11626.750000   4245.000000   1701.750000   3677.250000    43.100000
# 50%    16501.500000   6705.500000   2578.000000   5702.000000    45.600000
# 75%    23869.000000  10894.000000   4102.750000   9132.000000    48.400000
# max    57446.000000  38387.000000  15837.000000  28307.000000    66.900000
#
#                FTM           FTA          FT%           REB           AST  \
# count  1282.000000   1282.000000  1282.000000   1282.000000   1282.000000
# mean   1643.521061   2172.131825    74.800312   3500.407956   1846.002340
# ...

# %%
#More Number of Reb by Player
df2[df2.REB == df2.REB.max()]
# Out:
#              Player     GP    MIN    PTS    FGM    FGA   FG% 3PM 3PA 3P%  ...  \
# 6  Wilt Chamberlain  1,045  47859  31419  12681  23497  54.0              ...
#
#     FT%  OREB  DREB    REB   AST  STL  BLK TOV  eFG%   TS%
# 6  51.1              23924  4643                54.0  54.7
#
# [1 rows x 22 columns]

# %%
#Player with more rebs [Number of career points]
mem = df2[df2.REB == df2.REB.max()]
mem.PTS
# Out:
# 6    31419
# Name: PTS, dtype: int64

# %%
#Player with more rebs [Number Of Minutes]
mem.MIN
# Out:
# 6    47859
# Name: MIN, dtype: int64

# %%
#Player with more rebs[Games played]
mem.GP
# Out:
# 6    1,045
# Name: GP, dtype: object

# %%
#More Than 20,000 points
a=df2[df2.PTS>20000]
a
# Out:
#                  Player     GP    MIN    PTS    FGM    FGA   FG%   3PM   3PA  \
# 0   Kareem Abdul Jabbar  1,560  57446  38387  15837  28307  55.9     1    18
# 1           Karl Malone  1,476  54852  36928  13528  26210  51.6    85   310
# 2          LeBron James  1,265  48550  34241  12481  24781  50.4  1875  5453
# 3           Kobe Bryant  1,346  48643  33643  11719  26200  44.7  1827  5546
# 4        Michael Jordan  1,072  41010  32292  12192  24537  49.7   581  1778
# 5         Dirk Nowitzki  1,522  51367  31560  11169  23734  47.1  1982  5210
# 6      Wilt Chamberlain  1,045  47859  31419  12681  23497  54.0
# 7      Shaquille O'Neal  1,207  41917  28596  11330  19457  58.2     1    22
# 8          Moses Malone  1,329  45071  27409   9435  19225  49.1     8    80
# 9           Elvin Hayes  1,303  50000  27313  10976  24272  45.2     5    34
# 10      Hakeem Olajuwon  1,238  44218  26946  10749  20991  51.2    25   124
# ...

# %%
plt.figure(figsize=(20,8))
plt.title('Players with points greater than 20000')
b= sns.barplot(y= a.Player, x= a.PTS)
b.set(ylabel='Players', xlabel='Points')
# Out:
# [Text(0, 0.5, 'Players'), Text(0.5, 0, 'Points')]

# %%
df2[df2.AST == df2.AST.max()]
# Out:
#            Player     GP    MIN    PTS   FGM    FGA   FG%  3PM   3PA   3P%  \
# 46  John Stockton  1,504  47766  19711  7039  13658  51.5  845  2202  38.4
#
#     ...   FT%  OREB  DREB   REB    AST   STL  BLK   TOV  eFG%   TS%
# 46  ...  82.6   966  3085  4051  15806  3265  315  4244  54.6  60.8
#
# [1 rows x 22 columns]

# %%
df2[df2.GP == df2.GP.max()]
# Out:
#             Player   GP    MIN    PTS   FGM   FGA   FG%   3PM   3PA   3P%  \
# 307  Hedo Turkoglu  997  26700  11022  3851  9034  42.6  1246  3246  38.4
#
#      ...   FT%  OREB  DREB   REB   AST  STL  BLK   TOV  eFG%   TS%
# 307  ...  78.4   647  3324  3971  2832  750  299  1578  49.5  54.0
#
# [1 rows x 22 columns]

# %%
cor = df2.corr()
cor
# Out:
#            MIN       PTS       FGM       FGA       FG%       FTM       FTA  \
# MIN   1.000000  0.916483  0.913084  0.910685  0.185559  0.825209  0.826264
# PTS   0.916483  1.000000  0.992126  0.987370  0.176645  0.932754  0.920963
# FGM   0.913084  0.992126  1.000000  0.988011  0.214163  0.897148  0.892639
# FGA   0.910685  0.987370  0.988011  1.000000  0.087457  0.895404  0.881354
# FG%   0.185559  0.176645  0.214163  0.087457  1.000000  0.152648  0.196418
# FTM   0.825209  0.932754  0.897148  0.895404  0.152648  1.000000  0.985464
# FTA   0.826264  0.920963  0.892639  0.881354  0.196418  0.985464  1.000000
# FT%   0.199818  0.289122  0.254682  0.296923 -0.272887  0.263135  0.140949
# REB   0.706482  0.643396  0.659829  0.617793  0.350276  0.634266  0.706767
# AST   0.684448  0.635527  0.617349  0.645606 -0.061269  0.581873  0.545810
# eFG%  0.198628  0.170022  0.170994  0.074453  0.755440  0.064898  0.076166
# ...

# %%
sns.heatmap(cor)

# %%
part = ['MIN','PTS','AST']
df3 = df2[part]
df3
# Out:
#         MIN    PTS   AST
# 0     57446  38387  5660
# 1     54852  36928  5248
# 2     48550  34241  9346
# 3     48643  33643  6306
# 4     41010  32292  5633
# ...     ...    ...   ...
# 1277   5931   1072   105
# 1278   7056   1064    99
# 1279   4239   1014   186
# 1280   5335    975   181
# 1281   5966    716   250
#
# [1282 rows x 3 columns]

# %%
a = sns.PairGrid(df3)
a.map(plt.scatter)

# %%
a = sns.PairGrid(df2)
a.map(plt.scatter)

# %%
assist = df2.sort_values(by='AST', ascending =False) #Sorting By highest number of assists
print(assist)
print("John Stockton takes the TOP spot of all time in number of assists with 15806, Steven Hunter is the lowest with 79")
# Out:
#              Player     GP    MIN    PTS   FGM    FGA   FG%   3PM   3PA   3P%  \
# 46    John Stockton  1,504  47766  19711  7039  13658  51.5   845  2202  38.4
# 84       Jason Kidd  1,391  50116  17529  6219  15557  40.0  1988  5701  34.9
# 86       Steve Nash  1,217  38073  17387  6321  12892  49.0  1685  3939  42.8
# 229    Mark Jackson  1,296  39117  12489  4793  10731  44.7   734  2213  33.2
# 80    Magic Johnson    906  33245  17707  6211  11951  52.0   325  1074  30.3
# ...             ...    ...    ...    ...   ...    ...   ...   ...   ...   ...
# 1272       Don Reid    403   5373   1454   583   1099  53.0     0     1   0.0
# 1245    Steve Novak    467   5657   2177   751   1717  43.7   575  1337  43.0
# 1277  Jim McIlvaine    401   5931   1072   423    948  44.6     1    10  10.0
# 1278   Joel Anthony    490   7056   1064   398    776  51.3     0     0   0.0
# 1261  Steven Hunter    400   5991   1817   735   1313  56.0     0     1   0.0
#
# ...

# %%
minu = df2.sort_values(by='MIN', ascending =False) #Sorting with minutes
print(minu)
print('Jabbar played 57446 minutes thats insane for a individual player career')
# Out:
#                    Player     GP    MIN    PTS    FGM    FGA   FG%   3PM  \
# 0     Kareem Abdul Jabbar  1,560  57446  38387  15837  28307  55.9     1
# 1             Karl Malone  1,476  54852  36928  13528  26210  51.6    85
# 5           Dirk Nowitzki  1,522  51367  31560  11169  23734  47.1  1982
# 17          Kevin Garnett  1,462  50412  26071  10505  21142  49.7   174
# 84             Jason Kidd  1,391  50116  17529   6219  15557  40.0  1988
# ...                   ...    ...    ...    ...    ...    ...   ...   ...
# 1242        Charlie Davis    415   5050   2214    970   2152  45.1    19
# 1089       George Senesky    482   5032   3455   1279   4087  31.3
# 512             Joe Fulks    489   4490   8003   2824   9338  30.2
# 1279        Greg Dreiling    474   4239   1014    375    803  46.7     3
# 1223         John Mahnken    414   1352   2388    966   3557  27.2
#
#        3PA   3P%  ...   FT%  OREB   DREB    REB    AST   STL   BLK   TOV  \
# ...

# %% [markdown]
# # Still doing more analysis will attach the rest of it sooner
